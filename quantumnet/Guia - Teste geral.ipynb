# %% [markdown]
# #### Importando as dependências

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger
import random
Logger.activate(Logger)

# %% [markdown]
# #### Instânciando a rede e setando a topologia

# %%
rede = Network()
rede.set_ready_topology("Grade", 2, 3)
rede.draw()

# %% [markdown]
# #### Criando pares EPR

# %%
# alice = rede.get_host(0)
# bob = rede.get_host(1)

# %% [markdown]
# ##### Usando arestas aleatórias

# %%
arestas = list(rede.edges)
print(arestas)

#Randomizando arestas
aresta_aleatorias = random.sample(arestas, 1)[0]
print(aresta_aleatorias)

#atribuindo hosts a aresta
x,y = aresta_aleatorias
alice = rede.get_host(x)
bob = rede.get_host(y)
# Out:
# [(0, 3), (0, 1), (1, 4), (1, 2), (2, 5), (3, 4), (4, 5)]
# (4, 5)

# %%
#Fazer um for pra executar o protocolo pra cada aresta escolhida.
for aresta in arestas:
    x, y = aresta
    alice = rede.get_host(x)
    bob = rede.get_host(y)
    print(f"Aresta {aresta}: alice = {alice}, bob = {bob}")
    
    # Criação de pares EPR
    alice.add_qubit(Qubit(0))
    bob.add_qubit(Qubit(1))

    # Acessando a memória dos hosts
    print(alice.memory)
    print(bob.memory)
    print("Canais: ", rede.edges)

    # Usando as funções da camada física
    rede.start_hosts_and_channels()
    rede.physical.echp_on_replay(x, y)

    # acessando as arestas
    rede.edges[x, y]
# Out:
# 2024-05-29 11:39:12,614: Qubit 0 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,614: Qubit 1 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,615: Qubit 0 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,615: Qubit 0 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,615: Qubit 1 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,616: Qubit 1 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,616: Qubit 2 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,616: Qubit 2 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,617: Qubit 3 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,617: Qubit 3 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,617: Qubit 4 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,617: Qubit 4 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,618: Qubit 5 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,618: Qubit 5 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,618: Qubit 6 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,619: Qubit 6 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,619: Qubit 7 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,619: Qubit 7 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,620: Qubit 8 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,620: Qubit 8 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,620: Qubit 9 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,621: Qubit 9 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,621: Qubit 10 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,621: Qubit 10 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,622: Qubit 11 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,622: Qubit 11 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,622: Qubit 12 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,622: Qubit 12 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,623: Qubit 13 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,623: Qubit 13 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,623: Qubit 14 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,624: Qubit 14 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,624: Qubit 15 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,624: Qubit 15 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,625: Qubit 16 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,625: Qubit 16 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,625: Qubit 17 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,625: Qubit 17 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,626: Qubit 18 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,626: Qubit 18 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,626: Qubit 19 adicionado à memória do Host 1.
# 2024-05-29 11:39:12,627: Qubit 19 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-29 11:39:12,627: Qubit 20 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,627: Qubit 20 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,627: Qubit 21 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,628: Qubit 21 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,628: Qubit 22 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,628: Qubit 22 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,629: Qubit 23 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,629: Qubit 23 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,629: Qubit 24 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,630: Qubit 24 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,630: Qubit 25 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,630: Qubit 25 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,631: Qubit 26 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,631: Qubit 26 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,631: Qubit 27 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,632: Qubit 27 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,632: Qubit 28 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,632: Qubit 28 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,633: Qubit 29 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,633: Qubit 29 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-29 11:39:12,633: Qubit 30 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,633: Qubit 30 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,634: Qubit 31 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,634: Qubit 31 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,634: Qubit 32 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,635: Qubit 32 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,635: Qubit 33 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,635: Qubit 33 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,635: Qubit 34 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,636: Qubit 34 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,636: Qubit 35 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,636: Qubit 35 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,637: Qubit 36 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,637: Qubit 36 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,637: Qubit 37 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,637: Qubit 37 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,638: Qubit 38 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,638: Qubit 38 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,638: Qubit 39 adicionado à memória do Host 3.
# 2024-05-29 11:39:12,639: Qubit 39 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-29 11:39:12,639: Qubit 40 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,639: Qubit 40 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,640: Qubit 41 adicionado à memória do Host 4.
# 2024-05-29 11:39:12
adicionado à memória do Host 4.
# 2024-05-29 11:39:12,774: Qubit 220 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,775: Qubit 221 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,775: Qubit 221 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,775: Qubit 222 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,776: Qubit 222 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,776: Qubit 223 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,776: Qubit 223 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,777: Qubit 224 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,777: Qubit 224 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,777: Qubit 225 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,777: Qubit 225 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,778: Qubit 226 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,778: Qubit 226 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,778: Qubit 227 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,779: Qubit 227 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,779: Qubit 228 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,779: Qubit 228 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,780: Qubit 229 adicionado à memória do Host 4.
# 2024-05-29 11:39:12,780: Qubit 229 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-29 11:39:12,780: Qubit 230 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,780: Qubit 230 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,781: Qubit 231 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,781: Qubit 231 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,781: Qubit 232 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,782: Qubit 232 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,782: Qubit 233 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,782: Qubit 233 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,782: Qubit 234 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,783: Qubit 234 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,783: Qubit 235 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,783: Qubit 235 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,784: Qubit 236 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,784: Qubit 236 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,784: Qubit 237 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,785: Qubit 237 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,785: Qubit 238 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,785: Qubit 238 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,786: Qubit 239 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,786: Qubit 239 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,786: A fidelidade do qubit Qubit 199 with state None é 1.0
# 2024-05-29 11:39:12,786: A fidelidade do qubit Qubit 209 with state None é 1.0
# 2024-05-29 11:39:12,787: A fidelidade do qubit Qubit 199 with state None é 1.0
# 2024-05-29 11:39:12,787: A fidelidade do qubit Qubit 209 with state None é 1.0
# 2024-05-29 11:39:12,787: A probabilidade de sucesso do ECHP é 0.8865608119497391
# 2024-05-29 11:39:12,788: O protocolo ECHP_on_replay foi bem sucedido.
# 2024-05-29 11:39:12,788: Qubit 0 adicionado à memória do Host 2.
# 2024-05-29 11:39:12,788: Qubit 1 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,789: Qubit 240 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,789: Qubit 240 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,789: Qubit 241 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,789: Qubit 241 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,790: Qubit 242 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,790: Qubit 242 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-29 11:39:12,790: Qubit 243 adicionado à memória do Host 0.
# 2024-05-29 11:39:12,791: Qubit 243 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# Aresta (0, 3): alice = 0, bob = 3
# [<quantumnet.objects.qubit.Qubit object at 0x0000015B0B4F5790>]
# [<quantumnet.objects.qubit.Qubit object at 0x0000015B0BAC1460>]
# Canais:  [(0, 3), (0, 1), (1, 4), (1, 2), (2, 5), (3, 4), (4, 5)]
# Aresta (0, 1): alice = 0, bob = 1
# [<quantumnet.objects.qubit.Qubit object at 0x0000015B0B4F5790>, <quantumnet.objects.qubit.Qubit object at 0x0000015B241105C0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22CF4F80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B240E5580>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA20C80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BC0D4F0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A46B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA5E150>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA5E030>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA5E270>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26196600>]
# [<quantumnet.objects.qubit.Qubit object at 0x0000015B22CD6870>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA5E7E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A44A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B24159D60>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA5E7B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4B90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A49E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195CA0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4230>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4980>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261955B0>]
# Canais:  [(0, 3), (0, 1), (1, 4), (1, 2), (2, 5), (3, 4), (4, 5)]
# Aresta (1, 4): alice = 1, bob = 4
# [<quantumnet.objects.qubit.Qubit object at 0x0000015B22CD6870>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA5E7E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A44A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B24159D60>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA5E7B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4B90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A49E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195CA0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4230>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4980>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261955B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3FB0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3B30>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2450>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C23F0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F1BE0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2660>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C26C0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B24111280>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2780>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F3E60>]
# ...
# 2024-05-29 11:39:12,911: Qubit 413 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,911: Qubit 413 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,911: Qubit 414 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,912: Qubit 414 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,912: Qubit 415 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,912: Qubit 415 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,913: Qubit 416 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,913: Qubit 416 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,913: Qubit 417 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,914: Qubit 417 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,914: Qubit 418 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,914: Qubit 418 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,915: Qubit 419 adicionado à memória do Host 5.
# 2024-05-29 11:39:12,915: Qubit 419 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-29 11:39:12,915: A fidelidade do qubit Qubit 409 with state None é 1.0
# 2024-05-29 11:39:12,916: A fidelidade do qubit Qubit 419 with state None é 1.0
# 2024-05-29 11:39:12,916: A fidelidade do qubit Qubit 409 with state None é 1.0
# 2024-05-29 11:39:12,916: A fidelidade do qubit Qubit 419 with state None é 1.0
# 2024-05-29 11:39:12,917: A probabilidade de sucesso do ECHP é 0.8865608119497391
# 2024-05-29 11:39:12,917: O protocolo ECHP_on_replay foi bem sucedido.
# Aresta (3, 4): alice = 3, bob = 4
# [<quantumnet.objects.qubit.Qubit object at 0x0000015B0BAC1460>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2B10>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2E70>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2415B200>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C30B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2415B050>, <quantumnet.objects.qubit.Qubit object at 0x0000015B24112540>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2415B800>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2415B9B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B240BB770>, <quantumnet.objects.qubit.Qubit object at 0x0000015B24111F70>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C32C0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C33E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197F80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3680>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26194350>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2A80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2415B140>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26196540>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C35F0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C24E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2420>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2990>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2A50>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F29C0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2C30>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2C90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2415ADE0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2ED0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2F90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22E21880>, <quantumnet.objects.qubit.Qubit object at 0x0000015B262099A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F1370>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26209760>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22FE45C0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F1CA0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26209B20>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26209910>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26194200>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F1DC0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26221D00>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3260>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26194B90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B262227B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4C80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F35F0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26194F80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4C50>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623CE00>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22CF4890>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F17F0>]
# [<quantumnet.objects.qubit.Qubit object at 0x0000015B24110DA0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3C80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3E90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3170>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C33B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22D61A30>, <quantumnet.objects.qubit.Qubit object at 0x0000015B24110290>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F03B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3CE0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0860>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3800>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26196E40>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3950>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3B00>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3C20>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22CB6CC0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195DF0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3C50>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0080>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195C40>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3860>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3050>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F30E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F30B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2D80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F3290>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3200>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261970B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C31D0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197DA0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26209F70>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2000>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2240>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26209DF0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F1D00>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A420>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2270>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A5A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2690>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A6C0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26194E90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4860>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623D100>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195550>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623D3A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22F26330>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26196CF0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623D820>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4380>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A40B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26220A10>]
# Canais:  [(0, 3), (0, 1), (1, 4), (1, 2), (2, 5), (3, 4), (4, 5)]
# Aresta (4, 5): alice = 4, bob = 5
# [<quantumnet.objects.qubit.Qubit object at 0x0000015B24110DA0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3C80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3E90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3170>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C33B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22D61A30>, <quantumnet.objects.qubit.Qubit object at 0x0000015B24110290>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F03B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3CE0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0860>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3800>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26196E40>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3950>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3B00>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3C20>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22CB6CC0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195DF0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3C50>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0080>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195C40>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3860>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3050>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F30E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F30B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2D80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F3290>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3200>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261970B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C31D0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197DA0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26209F70>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2000>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2240>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26209DF0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F1D00>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A420>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2270>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A5A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2690>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A6C0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26194E90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4860>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623D100>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195550>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623D3A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22F26330>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26196CF0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623D820>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4380>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A40B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26220A10>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261971D0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197680>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4890>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197020>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197950>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA5F830>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195AC0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197D10>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623EA20>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A5F40>]
# [<quantumnet.objects.qubit.Qubit object at 0x0000015B261F00E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261A4350>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0C20>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26194BC0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B241590D0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3B60>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C12B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B23079A60>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261960F0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195FA0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0260>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3F80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0200>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F04A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0470>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F08C0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B22F24A70>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F05F0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197FE0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B24158920>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F3710>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F3950>, <quantumnet.objects.qubit.Qubit object at 0x0000015B0BA5E6F0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3920>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F3980>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F38C0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C3D40>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26196900>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620B020>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620BDD0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A840>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A510>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A960>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620AA80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620A780>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620ADE0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F2810>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620AD80>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620AF90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261C2900>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2620B0E0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195A90>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195B50>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261956D0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195CD0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F28A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26195D00>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0A70>, <quantumnet.objects.qubit.Qubit object at 0x0000015B262095B0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26196810>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197D70>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197B60>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623FB00>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197DD0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197EF0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26208080>, <quantumnet.objects.qubit.Qubit object at 0x0000015B26197EC0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B2623FCE0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B262081A0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F01D0>, <quantumnet.objects.qubit.Qubit object at 0x0000015B261F0140>]
# Canais:  [(0, 3), (0, 1), (1, 4), (1, 2), (2, 5), (3, 4), (4, 5)]
